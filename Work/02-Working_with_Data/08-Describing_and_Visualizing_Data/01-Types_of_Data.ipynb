# %% [markdown]
# # 📊 01 - Types of Data
#
# In order to analyze and visualize data properly, we first need to understand the **types of data** we're dealing with.
#
# This notebook covers:
# - Qualitative vs. Quantitative data
# - Discrete vs. Continuous data
# - The four scales of measurement: Nominal, Ordinal, Interval, Ratio
#
# > ⚡ Choosing the right summary statistic or plot depends on the data type!

# %% [markdown]
# ## 1. Qualitative vs. Quantitative
# - **Qualitative (Categorical)**: describes categories or labels.
#   - Example: eye color, brand of phone, type of pet
# - **Quantitative (Numeric)**: represents measurable quantities.
#   - Example: age, height, salary

# %%
# Example: classify the following
data = {
    'Eye Color': ['Blue', 'Brown', 'Green', 'Hazel'],
    'Age': [18, 21, 35, 42],
    'Favorite Pet': ['Dog', 'Cat', 'Fish', 'Bird'],
    'Height_cm': [160, 175, 180, 155],
}

import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Eye Color  Age Favorite Pet  Height_cm
# 0      Blue   18          Dog        160
# 1     Brown   21          Cat        175
# 2     Green   35         Fish        180
# 3     Hazel   42         Bird        155

# %% [markdown]
# ## 2. Discrete vs. Continuous
# - **Discrete**: countable values, often whole numbers.
#   - Example: number of children, dice rolls
# - **Continuous**: infinite possible values within a range.
#   - Example: height, weight, temperature
#
# > Note: both are *quantitative*, but treated differently in visualization and analysis.

# %% [markdown]
# ## 3. Scales of Measurement
# 1. **Nominal** — categories with no order (e.g. eye color, blood type).
# 2. **Ordinal** — categories with an order, but not evenly spaced (e.g. t-shirt size: S, M, L).
# 3. **Interval** — numeric, equal intervals, but no true zero (e.g. temperature in °C — 0°C doesn't mean "no temperature").
# 4. **Ratio** — numeric, equal intervals, *and* a meaningful zero (e.g. height, weight, age — 0 kg really does mean "no mass").

# %% [markdown]
# ### 🧠 Quick Check
# Why is temperature in °C **interval**, but height in cm **ratio**? (Hint: is $20°C$ "twice as hot" as $10°C$ in any meaningful physical sense? Is $180$cm "twice as tall" as $90$cm?)

# %% [markdown]
# ## 4. Practice: Classify These Variables

# %%
# Small exercise: classify the following
variables = [
    ('Movie Genre', 'Nominal'),
    ('Exam Letter Grade', 'Ordinal'),
    ('Temperature in Celsius', 'Interval'),
    ('Height in cm', 'Ratio'),
    ('Number of Siblings', 'Ratio'),
]
for var, classification in variables:
    print(f'{var} -> {classification}')
# Out:
# Movie Genre -> Nominal
# Exam Letter Grade -> Ordinal
# Temperature in Celsius -> Interval
# Height in cm -> Ratio
# Number of Siblings -> Ratio

# %% [markdown]
# 👉 **Task:** Edit the `'?'` values above with the correct scale of measurement (Nominal, Ordinal, Interval, or Ratio), then re-run the cell.

# %% [markdown]
# ## 5. A Trickier Case: Shoe Size
# Is shoe size **Interval** or **Ratio**? It's numeric and ordered, so it's tempting to call it Ratio — but is a size 12 shoe really "twice as much shoe" as a size 6? Shoe sizes don't measure a physical quantity directly (they're a manufacturer's labeling scale), and the gaps between sizes aren't perfectly consistent across brands. Most statisticians treat shoe size as **Ordinal**: you can rank it, but you shouldn't trust the arithmetic on it.

# %% [markdown]
# ## 6. Practice Table

# %% [markdown]
# | Variable | Qual/Quant | Disc/Cont | Scale |
# |----------|------------|-----------|-------|
# | Country of Birth | Qual |Discrete | Nominal|
# | Shoe Size | Quant | Discrete | Ordinal |
# | Time to Run 5k | Quant | Cont | Interval |
# | Temperature (°C) | Quant | Cont | Interval |
# | Number of Pets | Quant | Discrete | Ratio |
#
# 👉 **Task:** Fill in every `?` above (double-click this cell to edit it).

# %% [markdown]
# ## 🏋️ Practice

# %% [markdown]
# ### Practice 1 — Classify Your Own Data (easy)
# List 5 columns from any dataset you've used so far in this course (Titanic, Pokémon, UFO sightings, students — your choice), and classify each as qualitative or quantitative.

# %%
# Your classifications here (as a comment or a small dict/list)

Data_used = [
    ('Name of students', 'Qualitative'),
    ('Number of pets', 'Quantitative'),
    ('Temperature in Celsius', 'Quantitaive'),
    ('Score', 'Quantitaive'),
    ('Age', 'Quantitaive'),
]
for var, classification in Data_used:
    print(f'{var} -> {classification}')
# Out:
# Name of students -> Qualitative
# Number of pets -> Quantitative
# Temperature in Celsius -> Quantitaive
# Score -> Quantitaive
# Age -> Quantitaive

# %% [markdown]
# ### Practice 2 — Scale Justification (medium)
# For `Pclass` (passenger class: 1st/2nd/3rd) in the Titanic dataset, argue for **both** Nominal and Ordinal, then say which one you think is more defensible and why.

# %% [markdown]
# *Your answer here.*
# Pclass could be considered Nominal because the numbers 1, 2, and 3 act as category labels rather than measurements. However, it can also be considered Ordinal because the classes have a natural order, with 1st class ranking above 2nd class and 2nd class above 3rd class. I believe Ordinal is the more defensible classification because the ranking between categories is meaningful and important to the variable's interpretation.

# %% [markdown]
# ### Practice 3 — Design a Variable (harder)
# Invent one variable of each type — Nominal, Ordinal, Interval, and Ratio — that could plausibly appear in a survey about people's study habits. One sentence each.

# %% [markdown]
# *Your four variables here.*

# %% [markdown]
# ## 🔥 Challenge (Optional) — Why This Actually Matters
# Try computing a mean on something Nominal, like eye color encoded as numbers (`Blue=1, Brown=2, Green=3, Hazel=4`). What number do you get, and why is it meaningless even though Python will happily calculate it for you? This is the core reason data type matters — code won't stop you from computing nonsense, only understanding the data will.

# %%
eye_colors_encoded = [1, 2, 3, 4, 2, 1, 3]  # Blue, Brown, Green, Hazel...
# Compute the mean and explain in a comment why it doesn't mean anything

# %% [markdown]
# ---
# ✅ That's it for data types! Next up → [Summary Statistics](02-Summary_Statistics.ipynb)
