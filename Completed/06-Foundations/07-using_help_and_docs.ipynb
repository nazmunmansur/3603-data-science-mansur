# %% [markdown]
# # 📚 07 - Using Help and Documentation
#
# One of the most important skills in programming is knowing **how to get help**. Jupyter/IPython make it easy to explore functions, classes, and objects.
#
# This notebook covers:
# - Using `?` and `??` to view docstrings and source code
# - The built-in `help()` function
# - Tab completion for attributes and methods
# - Accessing external documentation

# %% [markdown]
# ## 1. Using `?` for Quick Help

# %%
len?  # Show help for the built-in len() function
# Out:
#   Cell In[1], line 1
#     len?  # Show help for the built-in len() function
#        ^
# SyntaxError: invalid syntax

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
print?  # Show help for print()

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# ✅ **Your Turn**: Use `?` to check the documentation for `range` and `dict`.

# %%
# Your turn here
range?
# Out:
# Init signature: range(self, /, *args, **kwargs)
# Docstring:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).
# Type:           type
# Subclasses:

# %%
dict?
# Out:
# Init signature: dict(self, /, *args, **kwargs)
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)
# Type:           type
# Subclasses:     OrderedDict, defaultdict, Counter, EnumDict, Bunch, _Quoter, ObjectDict, ConvertingDict, Config, _DefaultOptionDict, ...

# %% [markdown]
# ## 2. Using `??` for Source Code (if available)
# `??` tries to show you the actual source code, not just the docstring. It won't work for everything — some functions (like many built-ins) are implemented in C, not Python, so there's no Python source to show.

# %%
sum??  # Try to view source code for sum()

# %%
sum??
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and
# may reject non-numeric types.
# Type:      builtin_function_or_method

# %% [markdown]
# ✅ **Your Turn**: After `import pandas as pd`, use `??` on `pd.read_csv` to see if you can view more detail than `?` gave you.

# %%
# Your turn here
import pandas as pd
pd.read.csv??
# Out:
# Object `pd.read.csv` not found.

# %% [markdown]
# ## 3. The `help()` Function
# `help()` is the plain built-in Python equivalent of `?` — it works the same way outside of Jupyter too, e.g. in a plain `.py` script run from the terminal.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
import math
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %% [markdown]
# ✅ **Your Turn**: Use `help()` to explore `list.append` or `str.upper`.

# %%
# Your turn here
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %% [markdown]
# ## 4. Tab Completion

# %% [markdown]
# In a Jupyter cell, type an object name followed by a dot and press `Tab` to see available methods.
#
# Example:
# ```python
# mylist = []
# mylist.<TAB>
# ```
# will show you all methods like `append`, `clear`, `copy`, etc.

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary and use tab completion to explore its methods.

# %%
# Your turn here
# Create a dictionary
student = {
    "name": "Alice",
    "score": 95,
    "grade": "A"
}

# Type the line below and press Tab after the dot
student.clear
print(student.keys())
# Out:
# dict_keys(['name', 'score', 'grade'])

# %% [markdown]
# ## 5. External Documentation

# %% [markdown]
# - Many libraries (Pandas, NumPy, Matplotlib) have excellent online docs.
# - Example: [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)
# - A good search habit: `pandas read_csv site:pandas.pydata.org`, so you land on the official docs instead of a random blog post.

# %% [markdown]
# ✅ **Your Turn**: Look up the official documentation for Matplotlib's `plt.plot` online.

# %% [markdown]
# *Note what you found here.*
# # Matplotlib 3.11.2 documentation - Home
# - [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)
# - This site has so many information about ploting with different formating optiions like color, marker, and line.

# %% [markdown]
# ---
# ### Summary
# - `?` gives quick documentation.
# - `??` shows source if available.
# - `help()` is Python's built-in way, and works outside Jupyter too.
# - Tab completion speeds up discovery.
# - External docs are your best friend for deeper dives.

# %% [markdown]
# ## 🏋️ Practice

# %% [markdown]
# ### Practice 1 — Read Before You Ask (easy)
# Before looking anything up online, use `?` to answer: does `str.split()` split on *every* whitespace character by default, or just spaces? Write your answer as a comment.

# %%
# Your answer as a comment here
str.split?
# str.split() splits on all whitespace characters by default
# (spaces, tabs, and newline characters), not just spaces.
# Out:
# Signature: str.split(self, /, sep=None, maxsplit=-1)
# Docstring:
# Return a list of the substrings in the string, using sep as the separator string.
#
#   sep
#     The separator used to split the string.
#
#     When set to None (the default value), will split on any
#     whitespace character (including \n \r \t \f and spaces) and
#     will discard empty strings from the result.
#   maxsplit
#     Maximum number of splits.
#     -1 (the default value) means no limit.
#
# Splitting starts at the front of the string and works to the end.
#
# Note, str.split() is mainly useful for data that has been
# intentionally delimited.  With natural text that includes
# punctuation, consider using the regular expression module.
# Type:      method_descriptor

# %% [markdown]
# ### Practice 2 — Compare Two Functions (medium)
# Use `help()` on both `sorted()` and `list.sort()`. Write a one-line comment explaining the key difference between them (hint: what each one returns).

# %%
# Your comparison here
#- Sorted returns a list in ascending order however list.sort() returns none. 
sorted?
# Out:
# Signature: sorted(iterable, /, *, key=None, reverse=False)
# Docstring:
# Return a new list containing all items from the iterable in ascending order.
#
# A custom key function can be supplied to customize the sort order, and the
# reverse flag can be set to request the result in descending order.
# Type:      builtin_function_or_method

# %%
list.sort?
# Out:
# Signature: list.sort(self, /, *, key=None, reverse=False)
# Docstring:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable
# (i.e. the order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort
# them, ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.
# Type:      method_descriptor

# %% [markdown]
# ### Practice 3 — Find It Yourself (harder)
# Without searching online, use `?`, tab completion, and `dir()` on a string to find a string method you haven't used yet in this course. Try it out and explain what it does in a comment.

# %%
# Your discovery here
dir?
dir.__str__?
# Out:
# Signature:      dir.__str__()
# Call signature: dir.__str__(*args, **kwargs)
# Type:           method-wrapper
# String form:    <method-wrapper '__str__' of builtin_function_or_method object at 0x000001A4C6B2DE90>
# Namespace:      Python builtin
# Docstring:      Return str(self).

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# Use ? to learn about the method:
# str.swapcase?

text = "Hello Data Science!"
result = text.swapcase()
hash = text.__hash__()
print(result)
print(hash)

# swapcase() changes uppercase letters to lowercase
# and lowercase letters to uppercase.
# Example: "Hello Data Science!" becomes "hELLO dATA sCIENCE!"

# __hash__() returns an integer hash value for the string.
# Python uses hash values to efficiently store and find
# Out:
# hELLO dATA sCIENCE!
# -896495447793557085

# %% [markdown]
# ## 🔥 Challenge (Optional) — `dir()`
# `dir(obj)` lists *every* attribute and method an object has, not just the ones you'd guess. It's noisier than tab completion but sometimes turns up something useful.
# ```python
# print(dir('hello'))
# ```
# Try it on a list, a dictionary, and an integer. Do you notice the double-underscore (`__init__`, `__len__`, etc.) methods mixed in? Those are for later — you don't need them yet, but now you've seen where they live.

# %%
# Your dir() exploration here
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print(dir('hello'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(dir('text'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(dir(student.keys()))
# Out:
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'isdisjoint', 'mapping']
