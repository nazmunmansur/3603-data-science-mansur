# %% [markdown]
# # ⚡ 06 - Jupyter Shortcuts and Productivity
#
# Jupyter notebooks have **keyboard shortcuts and tricks** that make you faster.
#
# This notebook covers:
# - Command vs. Edit mode
# - Essential keyboard shortcuts
# - Saving and exporting notebooks
# - Using `%history` and `%save`

# %% [markdown]
# ## 1. Modes in Jupyter

# %% [markdown]
# - **Edit mode** (cursor blinking in a cell, ready to type)
# - **Command mode** (cell is selected, but you're not typing — shortcuts act on the whole cell)
#
# Switch:
# - Press `Enter` → Edit mode
# - Press `Esc` → Command mode

# %% [markdown]
# ✅ **Your Turn**: Click into a cell below, press `Esc`, then `Enter`, a few times, and notice how the cell's appearance changes between the two modes.

# %% [markdown]
# *Note what you observed here.*
# Presssing ESC is doing nothing if clicked. However,clicking Esc after Enter it is bringing back to the previous view. The edit mode went off when you click the Esc button and when you click Enter the edit cell opens. A

# %% [markdown]
# ## 2. Common Shortcuts

# %% [markdown]
# - `A` → Insert cell Above
# - `B` → Insert cell Below
# - `D D` → Delete a cell
# - `M` → Change to Markdown cell
# - `Y` → Change to Code cell
# - `Shift + Enter` → Run cell and move to next
# - `Ctrl + Enter` (`Cmd + Enter` on Mac) → Run cell, stay put
# - `Alt + Enter` (`Option + Enter` on Mac) → Run cell and insert a new one below

# %% [markdown]
# ✅ **Your Turn**: Practice creating, deleting, and changing cell types using only shortcuts (no mouse).

# %% [markdown]
# *Note what you observed here.*
# - A Inserted a cell
# - B Inseted a cell below
# - D D deleted the cell
# - M Changd to Markdown
# - Y changed to Code cell
# and other functions worked properly as described.

# %% [markdown]
# ## 3. Saving and Exporting

# %% [markdown]
# - `Ctrl + S` (`Cmd + S` on Mac) → Save the notebook
# - Menu: *File → Save and Export Notebook As…* → export to `.py`, `.html`, or `.pdf`
# - The workflow you're actually using in this course: save the notebook, then commit and push it with git/GitHub — see `_StartHere` if you need a refresher on that process.

# %% [markdown]
# ✅ **Your Turn**: Save this notebook, then try exporting it to `.py` or `.html` from the File menu.

# %% [markdown]
# *Note what you observed here.*

# %% [markdown]
# ## 4. History and Saving Code

# %%
# %history -n 1-5  # Show the first 5 commands in this session

# %%
# Save history to a file
# %save my_session.py 1-5
# Out:
# The following commands were written to file `my_session.py`:
# - `A` → Insert cell Above
# - `B` → Insert cell Below
# - `D D` → Delete a cell
# - `M` → Change to Markdown cell
# - `Y` → Change to Code cell
# - `Shift + Enter` → Run cell and move to next
# - `Ctrl + Enter` (`Cmd + Enter` on Mac) → Run cell, stay put
# - `Alt + Enter` (`Option + Enter` on Mac) → Run cell and insert a new one below
# # Save history to a file
# get_ipython().run_line_magic('save', 'my_session.py 1-5')

# %% [markdown]
# ✅ **Your Turn**: Use `%history` to view the last 10 commands you ran, then save them to `last10.py`.

# %%
# Your turn here
# %history
# Out:
# - `A` → Insert cell Above
# - `B` → Insert cell Below
# - `D D` → Delete a cell
# - `M` → Change to Markdown cell
# - `Y` → Change to Code cell
# - `Shift + Enter` → Run cell and move to next
# - `Ctrl + Enter` (`Cmd + Enter` on Mac) → Run cell, stay put
# - `Alt + Enter` (`Option + Enter` on Mac) → Run cell and insert a new one below
# # Save history to a file
# %save my_session.py 1-5
# # Your turn here
# %history -n -10
# # Your turn here
# %history

# %%
# %history
# %save last10.py - 10
# Out:
# - `A` → Insert cell Above
# - `B` → Insert cell Below
# - `D D` → Delete a cell
# - `M` → Change to Markdown cell
# - `Y` → Change to Code cell
# - `Shift + Enter` → Run cell and move to next
# - `Ctrl + Enter` (`Cmd + Enter` on Mac) → Run cell, stay put
# - `Alt + Enter` (`Option + Enter` on Mac) → Run cell and insert a new one below
# # Save history to a file
# %save my_session.py 1-5
# # Your turn here
# %history -n -10
# # Your turn here
# %history
# %save last10.py -10
# %save last10.py 10
# %save last10.py -n -10
# %save last10.py -10
# %save -f last10.py -10
# %save -f last10.py - 10
# %save last10.py - 10
# %history
# %save last10.py - 10
# The following commands were written to file `last10.py`:
# get_ipython().run_line_magic('save', '-f last10.py - 10')

# %% [markdown]
# ---
# ### Summary
# - Command vs. Edit mode controls how you interact with cells.
# - Shortcuts make notebook use much faster.
# - You can export notebooks to share, or turn them into scripts.
# - `%history` and `%save` help you capture your work.

# %% [markdown]
# ## 🏋️ Practice

# %% [markdown]
# ### Practice 1 — Speed Round (easy)
# Using only keyboard shortcuts: insert a new cell below this one, turn it into a Markdown cell, type a short note in it, and run it.

# %% [markdown]
# #SHORTCUTS ARE WORKING

# %% [markdown]
# ### Practice 2 — Reorganize Without a Mouse (medium)
# Insert 3 new cells, then use `Ctrl+Shift+-` to split a cell (place your cursor mid-line first), and move a cell up/down using the arrows in Command mode (usually the ⬆/⬇ toolbar icons, or drag — this one varies slightly by editor, so look it up if the shortcut doesn't match).

# %% [markdown]
# ### Practice 3 — Export and Inspect (harder)
# Export this notebook to `.py`. Open the exported file in VS Code and compare it to the notebook — what happened to the Markdown cells?

# %% [markdown]
# ## 🔥 Challenge (Optional) — Command Palette
# VS Code (and Jupyter itself) has a **Command Palette** — `Ctrl+Shift+P` (`Cmd+Shift+P` on Mac) — that lets you search for *any* command by typing part of its name, instead of memorizing every shortcut. Try opening it and searching for "Restart Kernel."
