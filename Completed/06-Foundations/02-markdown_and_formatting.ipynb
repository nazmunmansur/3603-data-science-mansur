# %% [markdown]
# # 📝 02 - Markdown and Formatting
#
# Jupyter notebooks aren't just for code — mixing **Markdown** and code lets you build clear, professional-looking reports.
#
# This notebook covers:
# - Writing Markdown cells (headings, lists, links)
# - Adding inline **LaTeX math**
# - Embedding images
# - Why formatting matters in data science communication

# %% [markdown]
# ## 1. Headings and Text Styles

# %% [markdown]
# ### Example
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# **Bold text**, *italic text*, `inline code`

# %% [markdown]
# ✅ **Your Turn**: Create a cell with the heading `## My Favorite Data Tools` and list at least three tools in bold.

# %% [markdown]
# ## My Favorite Data Tools
#
# - **Python**
# - **SQL**
# - **Power BI**

# %% [markdown]
# *Double-click this cell, replace this text with your answer, then run it (Shift+Enter).*

# %% [markdown]
# ## 2. Lists

# %% [markdown]
# ### Example
# - Item 1
# - Item 2
#   - Sub-item 2a
#   - Sub-item 2b
#
# 1. First
# 2. Second
# 3. Third

# %% [markdown]
# ✅ **Your Turn**: Make an ordered list of your top 3 programming languages.

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# # Top Programming languauge
# - Python
# - R
# - SPSS

# %% [markdown]
# ## 3. Links and Images

# %% [markdown]
# ### Links
# [OpenAI](https://www.openai.com)
#
# ### Images
# ![MSU Logo](https://upload.wikimedia.org/wikipedia/en/8/8b/Midwestern_State_University_seal.png)

# %% [markdown]
# ✅ **Your Turn**: Insert a link to your favorite website and embed an image (a URL or a local file both work).

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# ## My Favorite Data Tools
#
# - **Python**
# - **SQL**
# - **Power BI**
#
# My favorite website: [Python.org](https://www.python.org)
#
# ![Python www.python.org/static/community_logos/python-logo.png

# %% [markdown]
# ## 4. LaTeX Math

# %% [markdown]
# You can render math using LaTeX syntax inside `$ ... $` for inline or `$$ ... $$` for block math.
#
# Example:
# Inline: $E = mc^2$
# Block:
# $$
# \frac{\partial f}{\partial x} = 2x
# $$

# %% [markdown]
# ✅ **Your Turn**: Write the quadratic formula in LaTeX.

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# $$(a-b)^2 = a^2 - 2ab + b^2$$

# %% [markdown]
# ## 5. Mixing Code and Markdown

# %%
# Example: create data in Python
numbers = [1, 2, 3, 4, 5]
squares = [n**2 for n in numbers]
squares

# %% [markdown]
# Now we explain the results in Markdown:
# - The list `numbers` contained 1–5.
# - The list `squares` contains each number squared.
# - Mixing narrative and results is why notebooks are so powerful for data science reports.

# %% [markdown]
# ✅ **Your Turn**: Create a list of 3 numbers, calculate their cubes in code, then explain the result in a Markdown cell below it.

# %%
# Your code here
numbers = [2, 3, 4]

cubes = [n**3 for n in numbers]

print("Numbers:", numbers)
print("Cubes:", cubes)

# %% [markdown]
# *Your explanation here.*

# %% [markdown]
# ### Explanation
#
# The list contains the numbers 2, 3, and 4. Each number was raised to the power of 3 to calculate its cube.
#
# - \(2^3 = 8\)
# - \(3^3 = 27\)
# - \(4^3 = 64\)
#
# Therefore, the resulting list of cubes is `[8, 27, 64]`.

# %% [markdown]
# ---
# ### Summary
# - Use headings and formatting to organize.
# - Lists and links make content readable.
# - LaTeX lets you add professional math.
# - Combine code + Markdown for clear data storytelling.

# %% [markdown]
# ## 🏋️ Practice

# %% [markdown]
# ### Practice 1 — Table (easy)
# Markdown tables use `|` to separate columns and a `---` row to separate the header. Build a 3-row table listing a dataset name, its number of rows, and its source, in a cell below.

# %% [markdown]
# | Dataset | Rows | Source |
# |---------|------|--------|
# | *your answer* | | |

# %% [markdown]
# # Daily heat index
# |Days   |Temparature| Source  |
# |-------|-----------|---------|
# |Monday |100| Acu Weather     |
# |Tuesday|112| Fox News        |

# %% [markdown]
# ### Practice 2 — Blockquote and Code Block (medium)
# Use `>` for a blockquote and triple-backticks for a fenced code block to quote a definition of "data science" (your own words) followed by a short Python snippet that demonstrates it.

# %% [markdown]
# *Your blockquote and code block here.*

# %% [markdown]
# > Data science is the process of collecting, analyzing, and interpreting data to discover patterns, answer questions, and support decision-making. Data Science is getting more powerefull day by day.
#
# ```python
# numbers = [10, 20, 30, 40]
# average = sum(numbers) / len(numbers)
#
# print("Average:", average)
# ```

# %% [markdown]
# ### Practice 3 — Mini Report (harder)
# Combine a heading, a short paragraph, a bullet list, and one LaTeX equation into a single "mini report" cell about any topic of your choice.

# %% [markdown]
# *Your mini report here.*

# %% [markdown]
# # The Significance of R² (Coefficient of Determination)
#
# R², or the coefficient of determination, is a statistical measure that indicates how well a regression model explains the variation in a dependent variable. It is widely used in data science and analytics to evaluate the performance of predictive models.
#
# - Measures the proportion of variance explained by the model
# - Values range from 0 to 1
# - Higher R² values generally indicate a better fit
# - Helps compare different regression models
#
# ### R² Formula
#
# $$
# R^2 = 1 - \frac{SS_{res}}{SS_{tot}}
# $$
#
# Where:
# - $(SS_{res})$ = Sum of Squared Residuals
# - $(SS_{tot})$ = Total Sum of Squares
# `

# %% [markdown]
# ## 🔥 Challenge (Optional) — HTML Inside Markdown
# Markdown cells also render raw HTML. Try embedding a `<details>`/`<summary>` collapsible section — useful for hiding a long explanation or an answer key inside a notebook.
# ```html
# <details>
# <summary>Click to reveal</summary>
# Surprise!
# </details>
# ```

# %% [markdown]
# *Your collapsible section here.*

# %% [markdown]
# # Study Notes
#
# This notebook contains a brief explanation of R² and an answer key hidden below.
#
# <details>
# <summary>Click to reveal the explanation</summary>
#
# R² (the coefficient of determination) measures the proportion of the variance in the dependent variable that is explained by the regression model.
#
# - R² = 0 means the model explains none of the variation.
# - R² = 1 means the model explains all of the variation.
# - Higher values generally indicate a better fit, though a high R² does not always mean the model is appropriate.
#
# $$
# R^2 = 1 - \frac{SS_{res}}{SS_{tot}}
# $$
#
# </details>
