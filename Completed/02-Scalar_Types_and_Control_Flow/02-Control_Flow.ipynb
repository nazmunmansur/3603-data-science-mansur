# %% [markdown]
# # 📘 02 - Control Flow
#
# Learn how to use conditional logic in Python.

# %% [markdown]
# ## ✅ Learning Goals
# - Write `if`, `elif`, `else` statements — including branches with multiple lines
# - Understand truthy/falsy values
# - Combine conditions using `and`, `or`, `not`
# - Chain comparisons and write conditional expressions
# - Recognize `match`/`case` when you see it
# - If you know C++: see how each of these compares to what you already know

# %% [markdown]
# ## 🔧 Basic Example

# %%
age = 20
if age >= 18:
    print('You are an adult.')
else:
    print('You are a minor.')

# %% [markdown]
# ## 📦 One Branch, Many Lines
# A branch isn't limited to one statement. **Everything indented under the `if` (or `else`) runs together as a block** — as many lines as you need, as long as they stay indented at the same level.

# %%
cart_total = 84.50
is_member = True
#is_member = False

if is_member:
    discount = cart_total * 0.10
    final_total = cart_total - discount
    print(f'Member discount applied: -${discount:.2f}')
    print(f'Final total: ${final_total:.2f}')
else:
    final_total = cart_total
    print('No discount applied.')
    print(f'Final total: ${final_total:.2f}')
# Out:
# Member discount applied: -$8.45
# Final total: $76.05

# %% [markdown]
# ### 🧠 Quick Check 1
# Before you run it: if `is_member` were `False`, how many lines would print, and what would the second line say? Write down your guess, then change the cell above and re-run it to check.

# %% [markdown]
# ## 🔀 Multiple Branches

# %%
temp = 72
if temp > 90:
    print('Too hot!')
elif temp < 60:
    print('Too cold!')
else:
    print('Just right.')
# Out:
# Just right.

# %% [markdown]
# Just like a single `if`/`else`, each `elif`/`else` branch in a chain can hold multiple lines too:

# %%
#score = 78
score = 65

if score >= 90:
    letter = 'A'
    feedback = 'Excellent work!'
elif score >= 80:
    letter = 'B'
    feedback = 'Great job!'
elif score >= 70:
    letter = 'C'
    feedback = 'Solid effort, keep practicing.'
elif score >= 65:
    letter = 'D'
    feedback = 'You passed, but there is room for improvement.'
else:
    letter = 'F'
    feedback = "Let's review this together."

print(f'Grade: {letter}')
print(feedback)
# Out:
# Grade: D
# You passed, but there is room for improvement.

# %% [markdown]
# ### 🧠 Quick Check 2
# What prints if `score = 65`? Guess both lines before running it.

# %% [markdown]
# ## 🔗 Logical Operators
# Combine multiple conditions with `and`, `or`, and `not`.

# %%
age = 20
has_id = True
print(age >= 18 and has_id)
print(age < 13 or age > 65)
print(not has_id)
# Out:
# True
# False
# False

# %% [markdown]
# ### 🔀 Cross-Language Note: C++ Logical Operators
# If you've written C++, this is the same idea with different spelling — Python spells them out, C++ uses symbols:
#
# | Python | C++ |
# |--------|-----|
# | `and`  | `&&` |
# | `or`   | `\|\|` |
# | `not`  | `!` |
#
# ```cpp
# // C++
# bool age_ok = age >= 18 && has_id;
# bool out_of_range = age < 13 || age > 65;
# bool no_id = !has_id;
# ```
# Behavior-wise they work the same way (including short-circuiting) — it's really just syntax.

# %% [markdown]
# ## 🎯 Chained Comparisons
# Python lets you chain comparisons the way you'd write them on paper — `0 <= score <= 100` reads naturally and works exactly as you'd expect.

# %%
score = 85
print(0 <= score <= 100)

grade = 'B'
print('A' <= grade <= 'C')
# Out:
# True
# True

# %% [markdown]
# ### 🔀 Cross-Language Note: C++ Does NOT Have This
# This is a real gotcha if you're coming from C++: `0 <= score <= 100` is **legal C++ syntax**, but it does **not** mean what you'd think.
#
# ```cpp
# // C++ — this COMPILES but is almost certainly a bug!
# int score = 150;  // clearly out of range
# if (0 <= score <= 100) {
#     cout << "In range!" << endl;  // ...this prints anyway!
# }
# ```
#
# Why? C++ evaluates left to right: `(0 <= score)` produces a `bool`, which gets silently converted to `0` or `1` (an `int`). Then that `0`/`1` gets compared to `<= 100`, which is **always true**. The whole expression is always `true`, no matter what `score` is.
#
# The correct C++ version has to use `&&` explicitly:
# ```cpp
# if (0 <= score && score <= 100) { ... }
# ```
# Python's chained comparisons are a real language feature that actually does the right thing — not just shorthand.

# %% [markdown]
# ### 🧠 Quick Check 3
# What does `1 < 5 < 3` print in Python? Guess, then try it in the cell below.

# %%
print(1 < 5 < 3)
# Out:
# False

# %% [markdown]
# ## 🏋️ Practice

# %% [markdown]
# ### Practice 1 — Grade Letter (easy)
# Given `score = 82`, write an `if`/`elif`/`else` chain that prints the letter grade: `A` (90+), `B` (80-89), `C` (70-79), or `F` (below 70).

# %%
score = 82
# Your if/elif/else here

if score >= 90:
    letter = 'A'
    feedback = 'Excellent work!'
elif score >= 80:
    letter = 'B'
    feedback = 'Great job!'
elif score >= 70:
    letter = 'C'
    feedback = 'Solid effort, keep practicing.'
else:
    letter = 'F'
    feedback = "Let's review this together."

print(f'Grade: {letter}')
print(feedback)
# Out:
# Grade: B
# Great job!

# %% [markdown]
# ### Practice 2 — Combining Conditions (medium)
# Given `age = 16` and `has_ticket = True`, print `'Can ride'` only if the person is at least 13 **and** has a ticket. Otherwise print `'Cannot ride'`.

# %%
age = 16
has_ticket = True
# Your condition here
if age >= 13 and has_ticket:
    print(f'Can ride only if the person is at least 13 years old and has a ticket.')
else:
    print('Cannot ride.')
# Out:
# Can ride only if the person is at least 13 years old and has a ticket.

# %% [markdown]
# ### Practice 3 — Nested Conditions (harder)
# Given `password = 'Python123'`, check that it is **at least 8 characters long** AND **contains at least one digit** (hint: loop through the string and check `char.isdigit()`). Print `'Strong enough'` or `'Too weak'`.

# %%
password = 'Python123'
has_digit = False
# Your code here
for char in password:
    if char.isdigit():
        has_digit = True
        break

    if len(password) >= 8 and has_digit:
        print("Strong enough")
    else:
        print("Too weak")
# Out:
# Too weak
# Too weak
# Too weak
# Too weak
# Too weak
# Too weak

# %% [markdown]
# ### Practice 4 — Multi-Line Branches (harder)
# Given `distance_miles = 8.5` and `minutes = 42`, write an `if`/`else` where **each branch has at least three lines**: compute `pace = minutes / distance_miles`, then print the pace, and print `'Great pace!'` if pace is under 9 minutes/mile, or `'Keep training!'` otherwise.

# %%
distance_miles = 8.5
minutes = 42
# Your multi-line if/else here

# %% [markdown]
# ## ✏️ Your Turn
# Use `input()` to ask for the weather, then print:
# - `'Bring sunscreen'` if it's `'sunny'`
# - `'Take an umbrella'` if it's `'rainy'`
# - `'Check the forecast'` for anything else

# %%
#weather = input('What is the weather like? ')
weather = 'sunny'
# Your if/elif/else here
if weather == 'sunny':
        print('Bring sunscreen')
elif weather == 'rainy':
        print('Take an umbrella')
else:
        print('Check the forecast')
# Out:
# Bring sunscreen

# %% [markdown]
# ## 🧩 Match Statement (Preview)
# Since Python 3.10, there's another way to write a long chain of "is it this specific value, or this one, or this one..." checks: `match`/`case`. You are **not** required to use this in the course, but you should recognize it when you see it.
#
# If you know C++'s `switch`, this is the same idea, but more flexible — Python's `match` can work on strings (not just integers/enums) and can match multiple values in one `case` using `|`.

# %%
day = 'Sat'

match day:
    case 'Mon' | 'Tue' | 'Wed' | 'Thu' | 'Fri':
        print('Weekday')
    case 'Sat' | 'Sun':
        print('Weekend')
    case _:
        print('Not a valid day')
# Out:
# Weekend

# %% [markdown]
# ## 🔥 Challenge (Optional) — Conditional Expressions
# Python has a one-line if/else called a **conditional expression** (or "ternary"):
# ```python
# age = 20
# status = 'adult' if age >= 18 else 'minor'
# print(status)
# ```
# If you know C++, this is the same idea as `?:`, just reordered:
# ```cpp
# // C++ — condition comes first, same as Python
# string status = (age >= 18) ? "adult" : "minor";
# ```
# Python reads more like English (value-first), while C++ reads more like the underlying logic (condition-first, then the two outcomes).
#
# Try it: rewrite your Practice 1 grade-letter logic using nested conditional expressions (it gets messy fast — that's part of the lesson in when *not* to use them!).

# %%
age = 20
# Your conditional expression here
grade = 85
letter = ("A" if grade >= 90 else
          "B" if grade >= 80 else
          "C" if grade >= 70 else
          "D" if grade >= 60 else
          "F")
print(letter)
# Out:
# B
